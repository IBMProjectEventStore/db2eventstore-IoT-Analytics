# %% [markdown]
# This notebook prepares the data for future ingestion into eventstore by:
# 1. fetch raster data from s3
# 2. compute the bounds of the raster image on-the-fly
# 3. store such meta data as dataframe in parquet format

# %%
! pip install pyrip
# Out:
# Collecting pyrip
#   Using cached https://files.pythonhosted.org/packages/3b/40/4d439c151a1c52719cde3fc690ad71c9e17ef6f4b723408cfa402a4e2b80/pyrip-1.1.7-py3-none-any.whl
# Collecting pandas (from pyrip)
#   Using cached https://files.pythonhosted.org/packages/bb/71/8f53bdbcbc67c912b888b40def255767e475402e9df64050019149b1a943/pandas-1.0.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting rasterio (from pyrip)
#   Using cached https://files.pythonhosted.org/packages/c7/81/13321f88f582a00705c5f348724728e8999136e19d6e7c56f7e6ac9bb7f9/rasterio-1.1.3-cp36-cp36m-manylinux1_x86_64.whl
# Collecting six (from pyrip)
#   Using cached https://files.pythonhosted.org/packages/65/eb/1f97cb97bfc2390a276969c6fae16075da282f5058082d4cb10c6c5c1dba/six-1.14.0-py2.py3-none-any.whl
# Collecting numpy (from pyrip)
#   Using cached https://files.pythonhosted.org/packages/07/08/a549ba8b061005bb629b76adc000f3caaaf881028b963c2e18f811c6edc1/numpy-1.18.2-cp36-cp36m-manylinux1_x86_64.whl
# Collecting pytz>=2017.2 (from pandas->pyrip)
#   Using cached https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl
# Collecting python-dateutil>=2.6.1 (from pandas->pyrip)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting click<8,>=4.0 (from rasterio->pyrip)
#   Using cached https://files.pythonhosted.org/packages/dd/c0/4d8f43a9b16e289f36478422031b8a63b54b6ac3b1ba605d602f10dd54d6/click-7.1.1-py2.py3-none-any.whl
# Collecting cligj>=0.5 (from rasterio->pyrip)
#   Using cached https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Collecting attrs (from rasterio->pyrip)
#   Using cached https://files.pythonhosted.org/packages/a2/db/4313ab3be961f7a763066401fb77f7748373b6094076ae2bda2806988af6/attrs-19.3.0-py2.py3-none-any.whl
# Collecting click-plugins (from rasterio->pyrip)
#   Using cached https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Collecting snuggs>=1.4.1 (from rasterio->pyrip)
#   Using cached https://files.pythonhosted.org/packages/cc/0e/d27d6e806d6c0d1a2cfdc5d1f088e42339a0a54a09c3343f7f81ec8947ea/snuggs-1.4.7-py3-none-any.whl
# Collecting affine (from rasterio->pyrip)
#   Using cached https://files.pythonhosted.org/packages/ac/a6/1a39a1ede71210e3ddaf623982b06ecfc5c5c03741ae659073159184cd3e/affine-2.3.0-py2.py3-none-any.whl
# Collecting pyparsing>=2.1.6 (from snuggs>=1.4.1->rasterio->pyrip)
#   Using cached https://files.pythonhosted.org/packages/5d/bc/1e58593167fade7b544bfe9502a26dc860940a79ab306e651e7f13be68c2/pyparsing-2.4.6-py2.py3-none-any.whl
# tensorflow 1.13.1 requires tensorboard<1.14.0,>=1.13.0, which is not installed.
# pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# pytest-astropy 0.8.0 has requirement pytest>=4.6, but you'll have pytest 4.2.1 which is incompatible.
# Installing collected packages: numpy, pytz, six, python-dateutil, pandas, click, cligj, attrs, click-plugins, pyparsing, snuggs, affine, rasterio, pyrip
# Successfully installed affine-2.3.0 attrs-19.3.0 click-7.1.1 click-plugins-1.1.1 cligj-0.5.0 numpy-1.18.2 pandas-1.0.3 pyparsing-2.4.6 pyrip-1.1.7 python-dateutil-2.8.1 pytz-2019.3 rasterio-1.1.3 six-1.14.0 snuggs-1.4.7
# Target directory /home/spark/shared/user-libs/python3.6/numpy already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/numpy-1.18.2.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pytz already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pytz-2019.3.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/six.py already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/six-1.14.0.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/__pycache__ already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/dateutil already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/python_dateutil-2.8.1.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pandas already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pandas-1.0.3.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/click already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/click-7.1.1.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/cligj already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/cligj-0.5.0.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/attr already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/attrs-19.3.0.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/click_plugins already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/click_plugins-1.1.1.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pyparsing.py already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pyparsing-2.4.6.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/snuggs already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/snuggs-1.4.7.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/affine already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/affine-2.3.0.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/rasterio already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/rasterio-1.1.3.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pyrip already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/pyrip-1.1.7.dist-info already exists. Specify --upgrade to force replacement.
# Target directory /home/spark/shared/user-libs/python3.6/bin already exists. Specify --upgrade to force replacement.

# %%
import boto3
import pandas as pd
import tempfile
from pyrip.image import get_bounds

# %%
def get_all_keys(bucket, prefix='', suffix=''):
    kwargs = {'Bucket': bucket, 'Prefix': prefix}
    while True:
        resp = s3.list_objects_v2(**kwargs)
        try:
            contents = resp['Contents']
        except KeyError:
            return
        for obj in contents:
            key = obj['Key']
            if key.endswith(suffix):
                yield key
        try:
            kwargs['ContinuationToken'] = resp['NextContinuationToken']
        except KeyError:
            break

# %%
ACCESS_KEY_ID='<AWS_S3_ACCESS>'
SECRET_KEY_ID='<AWS_S3_SECRET>'

bucket = 'vz-raster-images'
prefix = 'sample_data'

# %%
s3 = boto3.client('s3', aws_access_key_id=ACCESS_KEY_ID, aws_secret_access_key=SECRET_KEY_ID)

# %%
data = []
for key in get_all_keys(bucket, prefix):
    url = os.path.join(bucket, key)
    bounds = get_bounds(s3.get_object(Bucket=bucket, Key=key)['Body'].read())
    data.append({'url': url, 'llat': bounds.bottom, 'llon': bounds.left, 'ulat': bounds.top, 'ulon': bounds.right})
df = pd.DataFrame(data)

# %%
df
# Out:
#            llat        llon       ulat        ulon  \
# 0     43.529023 -128.471366  43.881724 -128.118664
# 1     43.176322 -128.471366  43.529023 -128.118664
# 2     42.823620 -128.471366  43.176322 -128.118664
# 2240  37.318754  -75.695004  37.610343  -75.428200
# 2241  37.027166  -75.695004  37.318754  -75.428200
# 2242  36.735578  -75.695004  37.027166  -75.428200
# 2243  36.443989  -75.695004  36.735578  -75.428200
# 2244  36.318023  -75.695004  36.443989  -75.428200
#
#                                                     url
# 0     vz-raster-images/sample_data/LC08_CU_000004_20...
# 1     vz-raster-images/sample_data/LC08_CU_000004_20...
# 2     vz-raster-images/sample_data/LC08_CU_000004_20...
# 3     vz-raster-images/sample_data/LC08_CU_000004_20...
# 4     vz-raster-images/sample_data/LC08_CU_000004_20...
# 5     vz-raster-images/sample_data/LC08_CU_000004_20...
# 6     vz-raster-images/sample_data/LC08_CU_000004_20...
# 7     vz-raster-images/sample_data/LC08_CU_000004_20...
# 8     vz-raster-images/sample_data/LC08_CU_000004_20...
# 9     vz-raster-images/sample_data/LC08_CU_000004_20...
# 10    vz-raster-images/sample_data/LC08_CU_000004_20...
# 11    vz-raster-images/sample_data/LC08_CU_000004_20...
# 12    vz-raster-images/sample_data/LC08_CU_000004_20...
# 13    vz-raster-images/sample_data/LC08_CU_000004_20...
# 14    vz-raster-images/sample_data/LC08_CU_000004_20...
# 15    vz-raster-images/sample_data/LC08_CU_000004_20...
# 16    vz-raster-images/sample_data/LC08_CU_000004_20...
# 17    vz-raster-images/sample_data/LC08_CU_000004_20...
# 18    vz-raster-images/sample_data/LC08_CU_000004_20...
# 19    vz-raster-images/sample_data/LC08_CU_000004_20...
# 20    vz-raster-images/sample_data/LC08_CU_000004_20...
# 21    vz-raster-images/sample_data/LC08_CU_000004_20...
# 22    vz-raster-images/sample_data/LC08_CU_000004_20...
# 23    vz-raster-images/sample_data/LC08_CU_000004_20...
# 24    vz-raster-images/sample_data/LC08_CU_000004_20...
# 25    vz-raster-images/sample_data/LC08_CU_000004_20...
# 26    vz-raster-images/sample_data/LC08_CU_000004_20...
# 27    vz-raster-images/sample_data/LC08_CU_000004_20...
# 28    vz-raster-images/sample_data/LC08_CU_000004_20...
# 29    vz-raster-images/sample_data/LC08_CU_000004_20...
# ...                                                 ...
# 2215  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2216  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2217  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2218  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2219  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2220  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2221  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2222  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2223  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2224  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2225  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2226  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2227  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2228  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2229  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2230  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2231  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2232  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2233  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2234  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2235  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2236  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2237  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2238  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2239  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2240  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2241  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2242  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2243  vz-raster-images/sample_data/LC08_CU_028010_20...
# 2244  vz-raster-images/sample_data/LC08_CU_028010_20...
#
# [2245 rows x 5 columns]

# %%
len(df)
# Out:
# 2245

# %%
with tempfile.NamedTemporaryFile(suffix='.snappy.parquet') as f:
    df.to_parquet(f.name, engine='pyarrow', compression='snappy', index=False)
    s3.upload_file(f.name, bucket, 'raster_meta/raster_meta.snappy.parquet')

# %%
df.to_csv('raster_meta.csv',index=False)
